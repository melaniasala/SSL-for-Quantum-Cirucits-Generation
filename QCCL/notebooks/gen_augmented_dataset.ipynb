# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', '..')))

# %%
from QCCL.transformations.augmented_dataset import generate_augmented_dataset
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\melan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\melan\AppData\Local\Programs\Python\Python312\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
from Data import QuantumCircuitGraph
data, meta = generate_augmented_dataset("../../QCCL/dataset/raw/dataset_990_per_qubits/dataset_55_03.pkl")
# Out:
#   Cell In[3], line 2
#     data, meta = generate_augmented_dataset("../../QCCL/dataset/raw/dataset_990_per_qubits/dataset_55_03.pkl",
#                                                                                                               ^
# SyntaxError: incomplete input

# %%
data

# %%
import pickle
with open('augmented_dataset_3_qubits.pkl', 'rb') as f:
    data = pickle.load(f)
    print(data)
# Out:
# [{'sample_id': 0, 'statevector': [0.0, 0.0, 0.0, 0.0, 2.5023402338326227e-34, 2.5023402338326227e-34, 0.4999999999999998, 0.4999999999999998], 'views': {0: {'graph': <networkx.classes.digraph.DiGraph object at 0x000001FEBE1AF770>, 'quantum_circuit': <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x000001FEE9354E30>, 'transformations': []}, 1: {'graph': <networkx.classes.digraph.DiGraph object at 0x000001FEE93577D0>, 'circuit': <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x000001FEE33F9250>, 'transformations': ['add_identity']}, 2: {'graph': <networkx.classes.digraph.DiGraph object at 0x000001FEE33F9490>, 'circuit': <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x000001FEE33F9D30>, 'transformations': ['add_identity', 'add_identity']}, 3: {'graph': <networkx.classes.digraph.DiGraph object at 0x000001FEE8342960>, 'circuit': <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x000001FEE93DC6B0>, 'transformations': ['add_identity', 'remove_identity']}, 
# ...

# %%
import json
with open('metadata_3_qubits.json', 'r') as f:
    metadata = json.load(f)
metadata
# Out:
# '{\n    "dataset_info": {\n        "num_qubits": 3,\n        "num_samples": 16,\n        "num_views": 1273,\n        "timestamp": "2025-01-05T11:10:33.402047",\n        "statevector_dir": "statevectors_3_qubits"\n    },\n    "logs": {\n        "processed_count": 16,\n        "samples": {\n            "0": {\n                "successfully_applied": {\n                    "1": "add_identity",\n                    "2": "add_identity, add_identity",\n                    "3": "add_identity, remove_identity",\n                    "4": "add_identity, swap_ctrl_trgt",\n                    "5": "add_identity, cnot_decomp",\n                    "6": "add_identity, change_basis",\n                    "7": "add_identity, parallel_x",\n                    "8": "add_identity, commute_cnot_rot",\n                    "9": "add_identity, commute_cnots",\n                    "10": "add_identity, swap_cnots",\n                    "11": "remove_identity",\n                    "12": "remove_identity, add
# ...

# %%
metadata = json.loads(metadata)
metadata
# Out:
# {'dataset_info': {'num_qubits': 3,
#   'num_samples': 16,
#   'num_views': 1273,
#   'timestamp': '2025-01-05T11:10:33.402047',
#   'statevector_dir': 'statevectors_3_qubits'},
#  'logs': {'processed_count': 16,
#   'samples': {'0': {'successfully_applied': {'1': 'add_identity',
#      '2': 'add_identity, add_identity',
#      '3': 'add_identity, remove_identity',
#      '4': 'add_identity, swap_ctrl_trgt',
#      '5': 'add_identity, cnot_decomp',
#      '6': 'add_identity, change_basis',
#      '7': 'add_identity, parallel_x',
#      '8': 'add_identity, commute_cnot_rot',
#      '9': 'add_identity, commute_cnots',
#      '10': 'add_identity, swap_cnots',
#      '11': 'remove_identity',
#      '12': 'remove_identity, add_identity',
#      '13': 'remove_identity, swap_ctrl_trgt',
#      '14': 'remove_identity, cnot_decomp',
#      '15': 'remove_identity, change_basis',
#      '16': 'remove_identity, parallel_x',
#      '17': 'remove_identity, commute_cnot_rot',
# ...

# %%
counts = {}
for k in metadata['logs']['samples'].keys():
    print(k)
    print(metadata['logs']['samples'][k]['successful_count'])
    counts[k] = metadata['logs']['samples'][k]['successful_count']
counts
total = sum(counts.values()) + len(counts)
total
# Out:
# 0
# 85
# 1
# 69
# 2
# 42
# 3
# 90
# 4
# 88
# 5
# 63
# 6
# 73
# 7
# 83
# 8
# 93
# 9
# 71
# 10
# 73
# 11
# 107
# 12
# 72
# 13
# 90
# 1113

# %%
a = dict({'dataset_info': {'num_qubits': 3, 'num_samples': 10, 'num_views': 768, 'timestamp': '2025-01-05T10:32:28.650859', 'statevector_dir': 'statevectors_3_qubits'}})

# %%
a["dataset_info"]
# Out:
# {'num_qubits': 3,
#  'num_samples': 10,
#  'num_views': 768,
#  'timestamp': '2025-01-05T10:32:28.650859',
#  'statevector_dir': 'statevectors_3_qubits'}

# %%
json_str = json.dumps(a, indent=4)
print(json_str)
# Out:
# {
#     "dataset_info": {
#         "num_qubits": 3,
#         "num_samples": 10,
#         "num_views": 768,
#         "timestamp": "2025-01-05T10:32:28.650859",
#         "statevector_dir": "statevectors_3_qubits"
#     }
# }

# %%
with open('metadata_.json', 'w') as f:
    json.dump(json_str, f, indent=4)

# %%
with open('metadata_.json', 'r') as f:
    metadata = json.load(f)

# %%
metadata = json.loads(metadata)

# %%
metadata
# Out:
# {'dataset_info': {'num_qubits': 3,
#   'num_samples': 10,
#   'num_views': 768,
#   'timestamp': '2025-01-05T10:32:28.650859',
#   'statevector_dir': 'statevectors_3_qubits'}}

# %%
output_dir = os.mkdir(f"augmented_dataset_{56}_qubits")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 output_dir = os.mkdir(f"augmented_dataset_{56}_qubits")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'augmented_dataset_56_qubits'

# %%
print(output_dir)
# Out:
# None
